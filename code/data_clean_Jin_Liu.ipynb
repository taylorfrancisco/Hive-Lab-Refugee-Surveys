# %%
import pandas as pd

# Replace 'path_to_file.csv' with the path to your CSV file
csv_file_path = '/Users/jinliu/Desktop/Demo_all.csv'

# Read the CSV file
df = pd.read_csv(csv_file_path)

# %% [markdown]
# ## Data cleaning
# ### 1. Remove unnesscary columns
# The index column is just a duplicate of the DataFrame index, it could be dropped.
# ID related columns are unnesscary for analysis

# %%
# List of columns to be removed
columns_to_drop = ['index','documentation_id','ID']

# Drop the unnecessary columns
df = df.drop(columns_to_drop, axis=1)

# %% [markdown]
# ### 2. Assess Missing Values

# %% [markdown]
# Calculate NA percentages for each column and deal with them

# %%
# Calculate the percentage of missing values for each column
na_percentages = (df.isnull().sum() / len(df)) * 100

# Print the percentage of NA values for each column
print(na_percentages)
# Out:
# Year                             0.000000
# Quarter                          0.000000
# CountryOfAsylum                  0.418448
# nationality                      3.128073
# ethnicity                       65.918185
# intentionmove                   22.180047
# TotalAdult                       2.492397
# TotalMinor                       3.112066
# AppliedRefugee                  36.530766
# Childinschool                   55.358654
# Childvirtualed                  64.527931
# disabilityacc_disabilityserv     6.665447
# medicalReceived                 54.809869
# RiskYes                         31.687742
# RiskReturn_medical               1.294217
# RiskStay_medical                 6.214986
# dtype: float64

# %% [markdown]
# CountryOfAsylum missed out some values during the process of data merge

# %% [markdown]
# Column like ethnicity and disabilityacc_disabilityserv have a significant number of missing values and 0 and is not crucial for analysis

# %%
df = df.drop('ethnicity', axis=1)
df = df.drop('disabilityacc_disabilityserv', axis=1)
df = df.drop('RiskStay_medical', axis=1)

# %% [markdown]
# TotalAdult, TotalMinor:
# Retain all rows and the data distribution is not heavily skewed, impute missing values using the median.

# %%
df['TotalAdult'].fillna(df['TotalAdult'].median(), inplace=True)
df['TotalMinor'].fillna(df['TotalMinor'].median(), inplace=True)
df['RiskReturn_medical'].fillna(df['RiskReturn_medical'].median(), inplace=True)

# %% [markdown]
# When totalminor is 0, it means that parents have no children, so later columns that contain NA for education related should be clean.
#
# For rows where TotalMinor is 0, replace NA in Childvirtualed with 'Not Applicable' (or another appropriate value you choose).
#
# For rows where TotalMinor is greater than 0 and Childvirtualed is NA, decide on an imputation strategy (like replacing with the most frequent value, or a placeholder like 'Unknown').

# %%
# Step 1: Replace NA in 'Childvirtualed' with 'Not Applicable' when 'TotalMinor' is 0
df.loc[df['TotalMinor'] == 0, 'Childvirtualed'] = df.loc[df['TotalMinor'] == 0, 'Childvirtualed'].fillna('Not Applicable')

# Step 2: For 'TotalMinor' > 0, replace NA in 'Childvirtualed' with the most frequent value
most_frequent_value = df.loc[df['TotalMinor'] > 0, 'Childvirtualed'].mode()[0]
df.loc[df['TotalMinor'] > 0, 'Childvirtualed'] = df.loc[df['TotalMinor'] > 0, 'Childvirtualed'].fillna(most_frequent_value)

# %% [markdown]
# Do the same thing for Childinschool column

# %%
df.loc[df['TotalMinor'] == 0, 'Childinschool'] = df.loc[df['TotalMinor'] == 0, 'Childinschool'].fillna('Not Applicable')

most_frequent_value = df.loc[df['TotalMinor'] > 0, 'Childinschool'].mode()[0]
df.loc[df['TotalMinor'] > 0, 'Childinschool'] = df.loc[df['TotalMinor'] > 0, 'Childinschool'].fillna(most_frequent_value)

# %% [markdown]
# Impute Based on Other Columns: There is a pattern or correlation with other columns, I use this to infer the missing nationality. Certain nationalities are only found in specific CountryOfAsylum, I use this to impute the values.

# %%
# Create a dictionary to map 'CountryOfAsylum' to the most common 'nationality' (in lower case)
asylum_nationality_mapping = df.groupby('CountryOfAsylum')['nationality'].agg(lambda x: x.mode().iat[0].lower()).to_dict()

# Function to apply the mapping
def impute_nationality(row):
    if pd.isna(row['nationality']) and row['CountryOfAsylum'] in asylum_nationality_mapping:
        return asylum_nationality_mapping[row['CountryOfAsylum']]
    else:
        return row['nationality'].lower() if pd.notna(row['nationality']) else row['nationality']

# Apply the function to the 'nationality' column
df['nationality'] = df.apply(impute_nationality, axis=1)

# %% [markdown]
# Intentionmove column and AppliedRefugee:
# some people answer don'tknow as their answers,we can replace NA with Unknown to show that candidates didn't put answers

# %%
# Replace NA in these two columns with 'Unknown'
df['intentionmove'] = df['intentionmove'].fillna('Unknown')
df['AppliedRefugee'] = df['AppliedRefugee'].fillna('Unknown')
df['medicalReceived'] = df['medicalReceived'].fillna('Undecided')
df['RiskYes'] = df['RiskYes'].fillna('Undecided')

# %%
# Assuming df is your DataFrame
# Update CountryOfAsylum to "Argentina" where nationality is "venezuela"
df.loc[df['nationality'] == 'venezuela', 'CountryOfAsylum'] = 'Argentina'
print(df)
# Out:
#        Year Quarter CountryOfAsylum nationality intentionmove  TotalAdult  \
# 0      2020      Q4       Argentina   venezuela          stay         2.0
# 1      2020      Q4       Argentina   venezuela      dontknow         3.0
# 2      2020      Q4       Argentina   venezuela          stay         2.0
# 3      2020      Q4       Argentina   venezuela          stay         3.0
# 4      2020      Q4       Argentina   venezuela      relocate         2.0
# ...     ...     ...             ...         ...           ...         ...
# 43728  2021      Q4       Argentina   venezuela          stay         5.0
# 43729  2021      Q4       Argentina   venezuela          stay         1.0
# 43730  2021      Q4       Argentina   venezuela          stay         2.0
# 43731  2021      Q4       Argentina   venezuela          stay         3.0
# 43732  2021      Q4       Argentina   venezuela      relocate         3.0
#
#        TotalMinor AppliedRefugee   Childinschool     Childvirtualed  \
# 0             0.0    nointention  Not Applicable     Not Applicable
# 1             2.0        Unknown             yes                 no
# 2             2.0    nointention             yes                yes
# 3             1.0        Unknown             yes                yes
# 4             0.0    nointention  Not Applicable     Not Applicable
# ...           ...            ...             ...                ...
# 43728         3.0             no             yes  Nainpersonclasses
# 43729         0.0            yes  Not Applicable     Not Applicable
# 43730         3.0             no             yes                yes
# 43731         1.0             no             yes                 no
# 43732         1.0             no             yes                 no
#
#       medicalReceived        RiskYes  RiskReturn_medical
# 0       StronglyAgree  StronglyAgree                 1.0
# 1               Agree          Agree                 1.0
# 2       StronglyAgree          Agree                 0.0
# 3            Disagree          Agree                 1.0
# 4       StronglyAgree          Agree                 1.0
# ...               ...            ...                 ...
# 43728   StronglyAgree  StronglyAgree                 0.0
# 43729        Disagree  StronglyAgree                 0.0
# 43730           Agree          Agree                 0.0
# 43731   StronglyAgree  StronglyAgree                 0.0
# 43732   StronglyAgree          Agree                 1.0
#
# [43733 rows x 13 columns]

# %%
# Calculate the percentage of missing values for each column
na_percentages = (df.isnull().sum() / len(df)) * 100

# Print the percentage of NA values for each column
print(na_percentages)
# Out:
# Year                  0.0
# Quarter               0.0
# CountryOfAsylum       0.0
# nationality           0.0
# intentionmove         0.0
# TotalAdult            0.0
# TotalMinor            0.0
# AppliedRefugee        0.0
# Childinschool         0.0
# Childvirtualed        0.0
# medicalReceived       0.0
# RiskYes               0.0
# RiskReturn_medical    0.0
# dtype: float64

# %%
# Display a random 50 rows from the DataFrame with basic styling
styled_df = df.sample(50).style.set_table_styles(
    [{'selector': 'th', 'props': [('font-size', '10pt')]}]
).set_properties(**{'font-size': '9pt', 'border': '1px lightgrey solid !important'}).hide_index()

styled_df
# Out:
# /var/folders/4l/b27mglzj7235f2hz35t8jq9m0000gn/T/ipykernel_94211/200245136.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   styled_df = df.sample(50).style.set_table_styles(
# <style type="text/css">
# #T_752b5 th {
#   font-size: 10pt;
# }
# #T_752b5_row0_col0, #T_752b5_row0_col1, #T_752b5_row0_col2, #T_752b5_row0_col3, #T_752b5_row0_col4, #T_752b5_row0_col5, #T_752b5_row0_col6, #T_752b5_row0_col7, #T_752b5_row0_col8, #T_752b5_row0_col9, #T_752b5_row0_col10, #T_752b5_row0_col11, #T_752b5_row0_col12, #T_752b5_row1_col0, #T_752b5_row1_col1, #T_752b5_row1_col2, #T_752b5_row1_col3, #T_752b5_row1_col4, #T_752b5_row1_col5, #T_752b5_row1_col6, #T_752b5_row1_col7, #T_752b5_row1_col8, #T_752b5_row1_col9, #T_752b5_row1_col10, #T_752b5_row1_col11, #T_752b5_row1_col12, #T_752b5_row2_col0, #T_752b5_row2_col1, #T_752b5_row2_col2, #T_752b5_row2_col3, #T_752b5_row2_col4, #T_752b5_row2_col5, #T_752b5_row2_col6, #T_752b5_row2_col7, #T_752b5_row2_col8, #T_752b5_row2_col9, #T_752b5_row2_col10, #T_752b5_row2_col11, #T_752b5_row2_col12, #T_752b5_row3_col0, #T_752b5_row3_col1, #T_752b5_row3_col2, #T_752b5_row3_col3, #T_752b5_row3_col4, #T_752b5_row3_col5, #T_752b5_row3_col6, #T_752b5_row3_col7, #T_752b5_row3_col8, #T_752b5_row3_col9, #T_752b5_row3_col10, #T_752b5_row3_col11, #T_752b5_row3_col12, #T_752b5_row4_col0, #T_752b5_row4_col1, #T_752b5_row4_col2, #T_752b5_row4_col3, #T_752b5_row4_col4, #T_752b5_row4_col5, #T_752b5_row4_col6, #T_752b5_row4_col7, #T_752b5_row4_col8, #T_752b5_row4_col9, #T_752b5_row4_col10, #T_752b5_row4_col11, #T_752b5_row4_col12, #T_752b5_row5_col0, #T_752b5_row5_col1, #T_752b5_row5_col2, #T_752b5_row5_col3, #T_752b5_row5_col4, #T_752b5_row5_col5, #T_752b5_row5_col6, #T_752b5_row5_col7, #T_752b5_row5_col8, #T_752b5_row5_col9, #T_752b5_row5_col10, #T_752b5_row5_col11, #T_752b5_row5_col12, #T_752b5_row6_col0, #T_752b5_row6_col1, #T_752b5_row6_col2, #T_752b5_row6_col3, #T_752b5_row6_col4, #T_752b5_row6_col5, #T_752b5_row6_col6, #T_752b5_row6_col7, #T_752b5_row6_col8, #T_752b5_row6_col9, #T_752b5_row6_col10, #T_752b5_row6_col11, #T_752b5_row6_col12, #T_752b5_row7_col0, #T_752b5_row7_col1, #T_752b5_row7_col2, #T_752b5_row7_col3, #T_752b5_row7_col4, #T_752b5_row7_col5, #T_752b5_row7_col6, #T_752b5_row7_col7, #T_752b5_row7_col8, #T_752b5_row7_col9, #T_752b5_row7_col10, #T_752b5_row7_col11, #T_752b5_row7_col12, #T_752b5_row8_col0, #T_752b5_row8_col1, #T_752b5_row8_col2, #T_752b5_row8_col3, #T_752b5_row8_col4, #T_752b5_row8_col5, #T_752b5_row8_col6, #T_752b5_row8_col7, #T_752b5_row8_col8, #T_752b5_row8_col9, #T_752b5_row8_col10, #T_752b5_row8_col11, #T_752b5_row8_col12, #T_752b5_row9_col0, #T_752b5_row9_col1, #T_752b5_row9_col2, #T_752b5_row9_col3, #T_752b5_row9_col4, #T_752b5_row9_col5, #T_752b5_row9_col6, #T_752b5_row9_col7, #T_752b5_row9_col8, #T_752b5_row9_col9, #T_752b5_row9_col10, #T_752b5_row9_col11, #T_752b5_row9_col12, #T_752b5_row10_col0, #T_752b5_row10_col1, #T_752b5_row10_col2, #T_752b5_row10_col3, #T_752b5_row10_col4, #T_752b5_row10_col5, #T_752b5_row10_col6, #T_752b5_row10_col7, #T_752b5_row10_col8, #T_752b5_row10_col9, #T_752b5_row10_col10, #T_752b5_row10_col11, #T_752b5_row10_col12, #T_752b5_row11_col0, #T_752b5_row11_col1, #T_752b5_row11_col2, #T_752b5_row11_col3, #T_752b5_row11_col4, #T_752b5_row11_col5, #T_752b5_row11_col6, #T_752b5_row11_col7, #T_752b5_row11_col8, #T_752b5_row11_col9, #T_752b5_row11_col10, #T_752b5_row11_col11, #T_752b5_row11_col12, #T_752b5_row12_col0, #T_752b5_row12_col1, #T_752b5_row12_col2, #T_752b5_row12_col3, #T_752b5_row12_col4, #T_752b5_row12_col5, #T_752b5_row12_col6, #T_752b5_row12_col7, #T_752b5_row12_col8, #T_752b5_row12_col9, #T_752b5_row12_col10, #T_752b5_row12_col11, #T_752b5_row12_col12, #T_752b5_row13_col0, #T_752b5_row13_col1, #T_752b5_row13_col2, #T_752b5_row13_col3, #T_752b5_row13_col4, #T_752b5_row13_col5, #T_752b5_row13_col6, #T_752b5_row13_col7, #T_752b5_row13_col8, #T_752b5_row13_col9, #T_752b5_row13_col10, #T_752b5_row13_col11, #T_752b5_row13_col12, #T_752b5_row14_col0, #T_752b5_row14_col1, #T_752b5_row14_col2, #T_752b5_row14_col3, #T_752b5_row14_col4, #T_752b5_row14_col5, #T_752b5_row14_col6, #T_752b5_row14_col7, #T_752b5_row14_col8, #T_752b5_row14_col9, #T_752b5_row14_col10, #T_752b5_row14_col11, #T_752b5_row ...
